# %%
#entrada de dados
nome = input("Digite seu nome completo: ")
#saída de dados
print(f"Olá, {nome}!")
# Out:
# Olá, Fabricio Macedo!

# %%
numero1 = input('Escreva o primeiro numero: ')
numero2 = input('Escreva o segundo numero: ')

soma = int(numero1) + int(numero2) #casting em python - convertendo string para inteiro
print(f'A soma entre {numero1} + {numero2} é igual a {soma}')
# Out:
# A soma entre 8 + 3 é igual a 11

# %%
numero1 = int (input('Escreva o primeiro numero: '))
mumero2 = int (input('Escreva o segundo numero: '))

print(f' Numeros Digitados: {numero1} e {numero2}')

#Estrutura condicional simples
if numero1 == 15 or numero2 == 15:   #operador lógico "ou"
    print('Você ACERTOU!')
else:
    print('Você ERROU! Tente novamente.')
# Out:
#  Numeros Digitados: 15 e 3
# Você ACERTOU!
