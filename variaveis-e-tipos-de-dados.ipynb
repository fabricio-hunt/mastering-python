# %% [markdown]
# # Conceito de Variáveis

# %% [markdown]
# Variáveis são como "caixas" na memória do computador usadas para guardar informações.
# Essas informações podem ser números, textos, valores lógicos (verdadeiro/falso), listas, objetos etc.
#
# Em Python, uma variável é criada quando recebe um valor pela primeira vez.
# Exemplo:

# %%
idade = 25
nome = "Fabricio"
altura = 1.75

# %% [markdown]
# Em Python, as variáveis são dinâmicas, o que significa que você não precisa informar o tipo do dado antes de usá-la.
#
# Em outras linguagens, como Java ou C, você teria que escrever algo assim:
#
# int idade = 25; <br>
# float altura = 1.75; <br>
# String nome = "Ana"; <br>

# %% [markdown]
# # Tipos de Dados

# %% [markdown]
# Em Python, os tipos de dados definem o tipo de valor que uma variável pode armazenar. Python usa **tipagem dinâmica**, ou seja, o tipo é determinado automaticamente no momento da atribuição.
#
# ---
#
# ### 1️⃣ Numéricos
#
# | Tipo      | Exemplo       | Descrição                       |
# | --------- | ------------- | ------------------------------- |
# | `int`     | `10`, `-5`    | Números inteiros                |
# | `float`   | `3.14`, `0.5` | Números decimais                |
# | `complex` | `2+3j`        | Números complexos (menos comum) |
#
# ---
#
# ### 2️⃣ Texto
#
# | Tipo  | Exemplo          | Descrição            |
# | ----- | ---------------- | -------------------- |
# | `str` | `"Olá, Python!"` | Cadeia de caracteres |
#
# ---
#
# ### 3️⃣ Booleano
#
# | Tipo   | Exemplo         | Descrição                  |
# | ------ | --------------- | -------------------------- |
# | `bool` | `True`, `False` | Representa valores lógicos |
#
# ---
#
# ### 4️⃣ Coleções (Estruturas de Dados)
#
# | Tipo    | Exemplo                        | Características                   |
# | ------- | ------------------------------ | --------------------------------- |
# | `list`  | `[1, 2, 3]`                    | Mutável                           |
# | `tuple` | `(1, 2, 3)`                    | Imutável                          |
# | `set`   | `{1, 2, 3}`                    | Sem ordem e sem valores repetidos |
# | `dict`  | `{"nome": "Ana", "idade": 25}` | Armazena pares chave-valor        |
#
# ---
#
# ### 5️⃣ Tipo Especial
#
# | Tipo       | Exemplo | Descrição                    |
# | ---------- | ------- | ---------------------------- |
# | `NoneType` | `None`  | Representa ausência de valor |
#
# ---
#
# ## 🔍 Verificando o tipo de uma variável
#
# ```python
# type(10)
# type("Python")
# type([1, 2, 3])
# ```
#
# ---
#
# ## 🔁 Conversão entre tipos (Casting)
#
# ```python
# int(3.14)      # → 3
# float(10)      # → 10.0
# str(25)        # → "25"
# list("abc")    # → ['a', 'b', 'c']
# ```
